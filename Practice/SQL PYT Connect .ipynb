# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
from sqlalchemy import create_engine, text
import pandas as pd 
import os

# %%
engine1 = create_engine("mysql+pymysql://root:Mysql@123@localhost:3306/piit")
print(engine1)
# Out:
# Engine(mysql+pymysql://root:***@123@localhost:3306/piit)

# %%
def q(sql, **params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql), conn, params=params)

# %% [raw]
# q("SELECT * FROM students")

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse

# %%
def q(sql):
    return pd.read_sql(sql, engine1)

# %%
q("SELECT * FROM students")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pymysql/connections.py:661, in Connection.connect(self, sock)
#     660 try:
# --> 661     sock = socket.create_connection(
#     662         (self.host, self.port), self.connect_timeout, **kwargs
#     663     )
#     664     break
#
# File /opt/anaconda3/lib/python3.13/socket.py:840, in create_connection(address, timeout, source_address, all_errors)
#     839 exceptions = []
# --> 840 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     841     af, socktype, proto, canonname, sa = res
#
# File /opt/anaconda3/lib/python3.13/socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import urllib.parse

# %%
password = urllib.parse.quote_plus("Mysql@123")

# %%
engine1 = create_engine(f"mysql+pymysql://root:{password}@localhost:3306/piit")

# %%
def q(sql):
    return pd.read_sql(sql, engine1)

# %%
q("SELECT * FROM students")
# Out:
#     id                 name            branch  score   exam_date  \
# 0    1         Rick Johnson        Mechanical  63.68  2025-03-30
# 1    2         Shannon Hall        Electrical  74.35  2024-03-28
# 2    3     Stephanie Flores  Computer Science  88.97  2024-05-17
# 3    4        Keith Ferrell             Civil  75.00  2025-06-22
# 4    5          Corey Allen  Computer Science  63.14  2025-05-17
# 5    6    Brittney Galloway  Computer Science  51.85  2025-02-01
# 6    7       Kathryn Gordon        Electrical  70.88  2023-12-10
# 7    8         Julia Warren        Electrical  63.07  2023-11-21
# 8    9     Carol Cunningham  Computer Science  87.88  2024-07-29
# 9   10     Cassidy Crawford             Civil  52.46  2025-02-25
# 10  11      William Sanders       Electronics  53.81  2024-01-02
# 11  12       Amanda Chapman        Mechanical  58.49  2025-03-04
# 12  13         Amanda Reese       Electronics  54.26  2023-10-15
# ...

# %%
engine1.dispose()

# %%
q("SELECT * FROM emp")
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1980-12-17   800.0     NaN      20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02  2975.0     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09  2450.0     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1982-12-09  3000.0     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17  5000.0     NaN      10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08  1500.0     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1983-01-12  1100.0     NaN      20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03   950.0     NaN      30
# ...

# %%
q("SELECT * FROM dept")
# Out:
#    deptno       dname       loc
# 0    10.0  ACCOUNTING  NEW YORK
# 1    20.0    RESEARCH    DALLAS
# 2    30.0       SALES   CHICAGO
# 3    40.0  OPERATIONS    BOSTON
# 4    10.0  ACCOUNTING  NEW YORK
# 5    20.0    RESEARCH    DALLAS
# 6    30.0       SALES   CHICAGO
# 7    40.0  OPERATIONS    BOSTON

# %%
q('show tables')
# Out:
#   Tables_in_piit
# 0           dept
# 1            emp
# 2       students
