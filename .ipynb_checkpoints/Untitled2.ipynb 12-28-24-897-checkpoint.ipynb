# %%
# Pandas
# https://pandas.pydata.org

# %%
import pandas as pd

# %%
#pd.

# %% [markdown]
# # Set Pandas options for wrapping
# pd.set_option('display.max_columns', None)   # Show all columns
# pd.set_option('display.width', 100)          # Set line width before wrapping
# pd.set_option('display.max_colwidth', None)  # Don't truncate text

# %%
from pydataset import data  #load library of pydataset and import mtcars data from it
mtcars = data('mtcars')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
type(mtcars)
# Out:
# pandas.core.frame.DataFrame

# %%
mtcars.head ()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars.tail(4)
# Out:
#                  mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# Ford Pantera L  15.8    8  351.0  264  4.22  3.17  14.5   0   1     5     4
# Ferrari Dino    19.7    6  145.0  175  3.62  2.77  15.5   0   1     5     6
# Maserati Bora   15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# Volvo 142E      21.4    4  121.0  109  4.11  2.78  18.6   1   1     4     2

# %%
mtcars.info
# Out:
# <bound method DataFrame.info of                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
mtcars.iloc[:, 0:10:4]
# Out:
#                       mpg  drat  am
# Mazda RX4            21.0  3.90   1
# Mazda RX4 Wag        21.0  3.90   1
# Datsun 710           22.8  3.85   1
# Hornet 4 Drive       21.4  3.08   0
# Hornet Sportabout    18.7  3.15   0
# Valiant              18.1  2.76   0
# Duster 360           14.3  3.21   0
# Merc 240D            24.4  3.69   0
# Merc 230             22.8  3.92   0
# Merc 280             19.2  3.92   0
# Merc 280C            17.8  3.92   0
# Merc 450SE           16.4  3.07   0
# Merc 450SL           17.3  3.07   0
# Merc 450SLC          15.2  3.07   0
# Cadillac Fleetwood   10.4  2.93   0
# Lincoln Continental  10.4  3.00   0
# Chrysler Imperial    14.7  3.23   0
# Fiat 128             32.4  4.08   1
# Honda Civic          30.4  4.93   1
# Toyota Corolla       33.9  4.22   1
# Toyota Corona        21.5  3.70   0
# Dodge Challenger     15.5  2.76   0
# AMC Javelin          15.2  3.15   0
# Camaro Z28           13.3  3.73   0
# Pontiac Firebird     19.2  3.08   0
# ...

# %% [markdown]
# mtcars.describe()

# %%
# Make sure mtcars is properly loaded
# If you haven't loaded it yet, you can do:
# import pandas as pd
# mtcars = pd.read_csv('mtcars.csv')  # or wherever your data is stored

# %%
print(mtcars.describe())
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 describe(include='all')
#
# NameError: name 'describe' is not defined

# %%
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': ['a', 'b', 'c', 'd', 'e']
})

# %%
df.describe(include='all')

# %%
mtcars.nunique() #count of unique values of each col|

# %%
mtcars.to_csv('mtcarsdat.csv', index=False)

# %%
#change data types
mtcars.head(2)

# %%
from statsmodels.datasets import get_rdataset
mtcars=data('mtcars')
mtcars=mtcars.astype({'cyl': 'category', 'vs':'category', 'carb':'category', 'am':'category', 'gear':'category'})

# %%
print(mtcars.columns)

# %%
mtcars.isnull()

# %%
mtcars = mtcars.astype({ 'cyl':'category', 'vs': 'category', 'carb': 'category',
'am': 'category', 'gear': 'category' } )

# %%
mtcars.head(3)

# %%
mtcars.info()

# %%
mtcars['am']=mtcars['am'].replace({0:'automatic', 1:'manuel'})

# %%
mtcars.info

# %%
mtcars['gear'].value_counts()

# %%
mtcars['gear']=mtcars ['gear'].map({3:'gear3',4:'gear4', 5:'gear5'})
mtcars.head

# %%
mtcars['mpg'].max()

# %%
mtcars[mtcars['mpg']> 30]

# %%
mtcars['mpg'].min()

# %%
mtcars[mtcars['mpg'] == mtcars['mpg'].max()]

# %%
mtcars.describe()

# %%
mtcars['hp'].max()

# %%
mtcars['hp'].min()

# %%
bins = [0, 70, 150, 250, mtcars['hp'].max()]
labels = ['Low', 'Medium', 'High', 'VeryHigh']
mtcars['hp_level'] = pd.cut(mtcars['hp'], bins=bins, labels=labels, include_lowest=True)

# %%
mtcars['hp'].value_counts()

# %%
mtcars.dtypes

# %%
from pydataset import data
mtcars=data('mtcars')
mtcars.head ()

# %%
print(mtcars['am'].dtype)

# %%
mtcars.dtypes

# %%
mtcars.head(3)

# %%
mtcars.head(5)

# %%
mtcars.describe()

# %%
mtcars.describe(include='all')

# %%
mtcars['am'] = mtcars['am'].map({'0': 'auto', '1': 'manual'})
mtcars.head()

# %%
mtcars['mpg'].max()

# %%
mtcars[mtcars['mpg'] > 30].sort_values('mpg', ascending=False)

# %%
mtcars[mtcars['mpg'] == mtcars['mpg'].max()]

# %%
mtcars['vs']=mtcars['vs'].map({'0':'vshaped', '1':'straight'})
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec   vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46  NaN   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02  NaN   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61  NaN   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44  NaN   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02  NaN   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2
